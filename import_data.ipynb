# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/home/dslab/service_account.json'
print(os.environ['GOOGLE_APPLICATION_CREDENTIALS'])
from dg_ml_core.datastores import gcs_utils
from sqlalchemy import create_engine
import pandas as pd
from io import StringIO
# Out:
# /home/dslab/service_account.json

# %%
engine = create_engine('postgresql://dslab:dslab2018@localhost/dslab')
# Out:
# /home/dslab/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# # Import Traffic Data

# %%
# %%capture output
file_uris = gcs_utils.get_uris_with_prefix('gs://black-friday-18-data-dumps/onlineshop')
total_files = len(file_uris)
for idx, file_uri in enumerate(file_uris):
    print('Processing {} [{}/{}]'.format(file_uri, idx+1, total_files))
    content = gcs_utils.download_string(file_uri)
    df = pd.read_csv(StringIO(content), low_memory=False)
    df.to_sql('traffic', engine, if_exists='append')

# %%
print(output)
# Out:
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000000.csv [1/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000001.csv [2/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000002.csv [3/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000003.csv [4/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000004.csv [5/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000005.csv [6/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000006.csv [7/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000007.csv [8/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000008.csv [9/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000009.csv [10/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000010.csv [11/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000011.csv [12/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000012.csv [13/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000013.csv [14/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000014.csv [15/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000015.csv [16/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000016.csv [17/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000017.csv [18/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000018.csv [19/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000019.csv [20/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000020.csv [21/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000021.csv [22/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000022.csv [23/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000023.csv [24/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000024.csv [25/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000025.csv [26/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000026.csv [27/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000027.csv [28/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000028.csv [29/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000029.csv [30/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000030.csv [31/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000031.csv [32/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000032.csv [33/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000033.csv [34/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000034.csv [35/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000035.csv [36/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000036.csv [37/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000037.csv [38/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000038.csv [39/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000039.csv [40/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000040.csv [41/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000041.csv [42/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000042.csv [43/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000043.csv [44/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000044.csv [45/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000045.csv [46/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000046.csv [47/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000047.csv [48/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000048.csv [49/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000049.csv [50/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000050.csv [51/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000051.csv [52/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000052.csv [53/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000053.csv [54/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000054.csv [55/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000055.csv [56/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000056.csv [57/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000057.csv [58/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000058.csv [59/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000059.csv [60/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000060.csv [61/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000061.csv [62/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000062.csv [63/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000063.csv [64/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000064.csv [65/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000065.csv [66/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000066.csv [67/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000067.csv [68/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000068.csv [69/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000069.csv [70/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000070.csv [71/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000071.csv [72/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000072.csv [73/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000073.csv [74/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000074.csv [75/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000075.csv [76/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000076.csv [77/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000077.csv [78/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000078.csv [79/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000079.csv [80/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000080.csv [81/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000081.csv [82/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000082.csv [83/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000083.csv [84/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000084.csv [85/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000085.csv [86/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000086.csv [87/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000087.csv [88/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000088.csv [89/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000089.csv [90/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000090.csv [91/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000091.csv [92/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000092.csv [93/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000093.csv [94/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000094.csv [95/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000095.csv [96/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000096.csv [97/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000097.csv [98/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000098.csv [99/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000099.csv [100/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000100.csv [101/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000101.csv [102/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000102.csv [103/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000103.csv [104/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000104.csv [105/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000105.csv [106/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000106.csv [107/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000107.csv [108/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000108.csv [109/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000109.csv [110/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000110.csv [111/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000111.csv [112/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000112.csv [113/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000113.csv [114/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000114.csv [115/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000115.csv [116/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000116.csv [117/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000117.csv [118/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000118.csv [119/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000119.csv [120/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000120.csv [121/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000121.csv [122/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000122.csv [123/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000123.csv [124/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000124.csv [125/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000125.csv [126/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000126.csv [127/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000127.csv [128/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000128.csv [129/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000129.csv [130/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000130.csv [131/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000131.csv [132/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000132.csv [133/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000133.csv [134/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000134.csv [135/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000135.csv [136/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000136.csv [137/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000137.csv [138/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000138.csv [139/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000139.csv [140/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000140.csv [141/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000141.csv [142/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000142.csv [143/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000143.csv [144/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000144.csv [145/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000145.csv [146/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000146.csv [147/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000147.csv [148/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000148.csv [149/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000149.csv [150/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000150.csv [151/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000151.csv [152/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000152.csv [153/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000153.csv [154/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000154.csv [155/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000155.csv [156/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000156.csv [157/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000157.csv [158/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000158.csv [159/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000159.csv [160/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000160.csv [161/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000161.csv [162/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000162.csv [163/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000163.csv [164/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000164.csv [165/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000165.csv [166/167]
# Processing gs://black-friday-18-data-dumps/onlineshop/traffic_000000000166.csv [167/167]

# %% [markdown]
# # Import Product Data

# %%
#%%capture output
import re

def get_row_iterator(filename):
    short_lines = []
    long_lines = []
    with open(filename) as f:
        for line in f:
            splits = line.split(',')
            if len(splits) < 11:
                short_lines.append(line)
                continue
            elif len(splits) > 11:
                long_lines.append(line)
                continue
            else:
                yield splits
    with open('/home/dslab/products/short_lines.csv', 'a') as f:
        f.writelines(short_lines)
    with open('/home/dslab/products/long_lines.csv', 'a') as f:
        f.writelines(long_lines)

files = os.listdir('/home/dslab/products/')
total_files = len(files)
for idx, file in enumerate(files):
    if 'split_' in file:
        print('Processing {} [{}/{}]'.format(file, idx+1, total_files))
#         rows = get_row_iterator('/home/dslab/products/' + file)
#         cols = next(rows)
#         df = pd.DataFrame(rows, columns=cols)
        df = pd.read_csv('/home/dslab/products/' + file)
        print('Inserting into db..')
        df.to_sql('product_only_ids', engine, if_exists='append')
# Out:
# Processing split_at [1/31]
# Inserting into db..
# Processing split_ax [3/31]
# Inserting into db..
# Processing split_aq [4/31]
# Inserting into db..
# Processing split_ag [5/31]
# Inserting into db..
# Processing split_as [6/31]
# Inserting into db..
# Processing split_am [7/31]
# Inserting into db..
# Processing split_ab [8/31]
# Inserting into db..
# Processing split_ad [9/31]
# Inserting into db..
# Processing split_ao [10/31]
# Inserting into db..
# Processing split_ac [12/31]
# Inserting into db..
# Processing split_af [15/31]
# Inserting into db..
# Processing split_aa [16/31]
# Inserting into db..
# Processing split_ae [17/31]
# Inserting into db..
# Processing split_aw [18/31]
# Inserting into db..
# Processing split_au [19/31]
# Inserting into db..
# Processing split_an [20/31]
# Inserting into db..
# Processing split_aj [21/31]
# Inserting into db..
# Processing split_al [24/31]
# Inserting into db..
# Processing split_ai [25/31]
# Inserting into db..
# Processing split_ak [26/31]
# Inserting into db..
# Processing split_ar [27/31]
# Inserting into db..
# Processing split_ah [28/31]
# Inserting into db..
# Processing split_av [29/31]
# Inserting into db..
# Processing split_ap [30/31]
# Inserting into db..

# %%
print(output)

# %% [markdown]
# # Import Order Data

# %%
file_uris = gcs_utils.get_uris_with_prefix('gs://raw-data-dumps/product_purchase_20181009')
total_files = len(file_uris)
for idx, file_uri in enumerate(file_uris):
    print('Processing {} [{}/{}]'.format(file_uri, idx+1, total_files))
    content = gcs_utils.download_string(file_uri)
    df = pd.read_csv(StringIO(content), low_memory=False)
    df.to_sql('product_purchase', engine, if_exists='append')
# Out:
# Processing gs://raw-data-dumps/product_purchase_20181009/product_purchase_000000000000.csv
# Processing gs://raw-data-dumps/product_purchase_20181009/product_purchase_000000000001.csv
# Processing gs://raw-data-dumps/product_purchase_20181009/product_purchase_000000000002.csv
# Processing gs://raw-data-dumps/product_purchase_20181009/product_purchase_000000000003.csv
# Processing gs://raw-data-dumps/product_purchase_20181009/product_purchase_000000000004.csv
# Processing gs://raw-data-dumps/product_purchase_20181009/product_purchase_000000000005.csv
# Processing gs://raw-data-dumps/product_purchase_20181009/product_purchase_000000000006.csv
# Processing gs://raw-data-dumps/product_purchase_20181009/product_purchase_000000000007.csv
# Processing gs://raw-data-dumps/product_purchase_20181009/product_purchase_000000000008.csv
