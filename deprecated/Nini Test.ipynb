# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('postgresql://dslab:dslab2018@localhost/dslab')
c = engine.connect()
# Out:
# /home/dslab/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# PropertyGroup is for example Width, Table Properties or RAM
# PropertyDefinition is for example Shape, Size or Ram Type
# PropertyDefinitions have a Type. 
# - Either its just a value -> TODO
# - If we have a fixed set of options they are PropertyDefinitionOption objects.
# PropertyDefinitionOption is actually a choice of Shape or RAM Type
# A Property links a ProductType a ProductDefinition and a Product Group
# A Property itself can also take one or multiple values -> TODO

# The parser handles the query string on pages that support filtering.
# The output is represents the currently selected options 

import json

def handle_opt(opt, result):
    '''
    This section handles properties that either directly have a primitive type value (bool, multidimensional properties)
    or Properties that link a PropertyGroup and PropertyDefinition which again map directly to a primitive type value.
    The Properties that directly have a primitive value will have the value in the coloumn PropertyValue
    Also the properties with a list of possible values will have the value in the coloumn PropertyValue
    '''
    parts = opt.split('|')
    for part in parts:
        # Boolean properties
        if part[0] == 't' or part[0] == 'f':
            property_id = int(part[1:])
            
            if 'Property' not in result:
                result['Property'] = dict()
            result['Property'][property_id] = 1 if part[0] == 't' else 0
        
        # Multidimensional properties
        if part[0] == 'm':
            prefix, values = part.split(':')
            property_id = int(prefix[1:])
            values = values.split(',')
            
            if 'Property' not in result:
                result['Property'] = dict()
            result['Property'][property_id] = values
        
        # Single Value properties
        if part[0] == 'v':
            prefix, value = part.split(':')
            if '~' in prefix:
                continue
            property_group_id, property_definition_id = prefix[1:].split('-')
            
            if 'PropertyGroup' not in result:
                result['PropertyGroup'] = dict()
            if property_group_id not in result:
                result['PropertyGroup'][property_group_id] = dict()
            if 'PropertyDefinition' not in result['PropertyGroup'][property_group_id]:
                result['PropertyGroup'][property_group_id]['PropertyDefinition'] = dict()
                
            result['PropertyGroup'][property_group_id]['PropertyDefinition'][property_definition_id] = value
            
    return result

def handle_bra(section, result):
    '''
    This section handles Brands.
    Example:
    https://www.galaxus.ch/de/s1/producttype/notebook-6?bra=1|47&tagIds=614
    ProductType 6 (Notebook)
    Selected are the Brands 1 (ASUS) and 47 (Apple)
    '''
    brand_ids = section.split('|')
    result['Brands'] = brand_ids
    return result

def handle_rng_rou(section, result):
    '''
    This section handles ranges.
    I.e. Table Width for example.
    The min and max values are to be found in the coloumn PropertyValue
    '''
    tuples = section.split('|')
    for tup in tuples:
        prefix, suffix = tup.split(':')
        if '~' in prefix:
            continue
        property_group_id, property_definition_id = prefix.split('-')
        minimum, maximum = suffix.split(',')
        if 'PropertyGroup' not in result:
            result['PropertyGroup'] = dict()
        if property_group_id not in result:
            result['PropertyGroup'][property_group_id] = dict()
        if 'PropertyDefinition' not in result['PropertyGroup'][property_group_id]:
            result['PropertyGroup'][property_group_id]['PropertyDefinition'] = dict()
        result['PropertyGroup'][property_group_id]['PropertyDefinition'][property_definition_id] = dict()
        result['PropertyGroup'][property_group_id]['PropertyDefinition'][property_definition_id]['Min'] = minimum
        result['PropertyGroup'][property_group_id]['PropertyDefinition'][property_definition_id]['Max'] = maximum
    return result

def handle_pdo(section, result):
    '''
    This section handles ProductPropertyOptions.
    These represent the fixed sets of options there are on a specific product type
    Example:
    https://www.galaxus.ch/de/s1/producttype/notebook-6?pdo=13-6885:277226&tagIds=614
    ProductType 6 (Notebook)
    Selected is the PropertyDefinitionOption 277226 (Windows 10 Pro)
    This is a option of the PropertyDefinition 6885 (Windows Version)
    This again is a definition in the PropertyGroup 13 (Operating System)
    '''
    parts = section.split('|')
    for part in parts:
        prefix, property_definition_option_id = part.split(':')
        if '~' in prefix:
            continue
        property_group_id, property_definition_id = prefix.split('-')
        if 'PropertyGroup' not in result:
            result['PropertyGroup'] = dict()
        if property_group_id not in result:
            result['PropertyGroup'][property_group_id] = dict()
        if 'PropertyDefinition' not in result['PropertyGroup'][property_group_id]:
            result['PropertyGroup'][property_group_id]['PropertyDefinition'] = dict()
        if property_definition_id not in result['PropertyGroup'][property_group_id]['PropertyDefinition']:
            result['PropertyGroup'][property_group_id]['PropertyDefinition'][property_definition_id] = dict()
        if 'PropertyDefinitionOptionIds' in result['PropertyGroup'][property_group_id]['PropertyDefinition'][property_definition_id]:
            result['PropertyGroup'][property_group_id]['PropertyDefinition'][property_definition_id]['PropertyDefinitionOptionIds'].append(property_definition_option_id)
        else:
            result['PropertyGroup'][property_group_id]['PropertyDefinition'][property_definition_id]['PropertyDefinitionOptionIds'] = [property_definition_option_id]

    return result
    
def handle_section(section, result):
    if (section[:3] == 'opt'):
        result = handle_opt(section[4:], result)
    if (section[:3] == 'bra'):
        result = handle_bra(section[4:], result)
    if (section[:3] == 'rng' or section[:3] == 'rou'):
        result = handle_rng_rou(section[4:], result)
    if (section[:3] == 'pdo'):
        result = handle_pdo(section[4:], result)
    return result

def parse_query_string(query_string):
    sections = query_string.split('&')
    result = dict()
    for section in sections:
        print(section)
        result = handle_section(section, result)
    print(json.dumps(result, indent=2))

example_qstring = 'opt=t44|m141:1,-2,3.14159,4,5|v3125-598080:6&bra=3301&nov=1:-30|2:15&rng=12-123:0.667,5|12-124:-2.7,1.414&rou=11-125:4,6.283|11-126:2.7,4&pdo=3126-598081:132|344-576:298&p=7667:1928|5123:1815&rfb=1&sale=1&pr=1&sr=1'
parse_query_string(example_qstring)
# Out:
# opt=t44|m141:1,-2,3.14159,4,5|v3125-598080:6
# bra=3301
# nov=1:-30|2:15
# rng=12-123:0.667,5|12-124:-2.7,1.414
# rou=11-125:4,6.283|11-126:2.7,4
# pdo=3126-598081:132|344-576:298
# p=7667:1928|5123:1815
# rfb=1
# sale=1
# pr=1
# sr=1
# {
#   "Brands": [
#     "3301"
#   ],
#   "Property": {
#     "44": 1,
#     "141": [
#       "1",
#       "-2",
#       "3.14159",
#       "4",
#       "5"
#     ]
#   },
#   "PropertyGroup": {
#     "344": {
#       "PropertyDefinition": {
#         "576": {
#           "PropertyDefinitionOptionIds": [
#             "298"
#           ]
#         }
#       }
#     },
#     "11": {
#       "PropertyDefinition": {
#         "126": {
#           "Max": "4",
#           "Min": "2.7"
#         }
#       }
#     },
#     "3125": {
#       "PropertyDefinition": {
#         "598080": "6"
#       }
#     },
#     "3126": {
#       "PropertyDefinition": {
#         "598081": {
#           "PropertyDefinitionOptionIds": [
#             "132"
#           ]
#         }
#       }
#     },
#     "12": {
#       "PropertyDefinition": {
#         "124": {
#           "Max": "1.414",
#           "Min": "-2.7"
#         }
#       }
#     }
#   }
# }

# %%
pd.read_sql_query('''
          select *
from INFORMATION_SCHEMA.COLUMNS
where TABLE_NAME='product'
          ''', c)
# Out:
#    table_catalog table_schema table_name                 column_name  \
# 0          dslab       public    product                       index
# 1          dslab       public    product                  ﻿ProductId
# 2          dslab       public    product                     BrandId
# 3          dslab       public    product               ProductTypeId
# 4          dslab       public    product                  PropertyId
# 5          dslab       public    product               PropertyValue
# 6          dslab       public    product             PropertyGroupId
# 7          dslab       public    product               PropertyGroup
# 8          dslab       public    product        PropertyDefinitionId
# 9          dslab       public    product          PropertyDefinition
# 10         dslab       public    product  PropertyDefinitionOptionId
# 11         dslab       public    product  PropertyDefinitionOption\n
#
#     ordinal_position column_default is_nullable data_type  \
# 0                  1           None         YES    bigint
# 1                  2           None         YES      text
# 2                  3           None         YES      text
# 3                  4           None         YES      text
# 4                  5           None         YES      text
# 5                  6           None         YES      text
# 6                  7           None         YES      text
# 7                  8           None         YES      text
# 8                  9           None         YES      text
# 9                 10           None         YES      text
# 10                11           None         YES      text
# 11                12           None         YES      text
#
#    character_maximum_length  character_octet_length     ...       is_identity  \
# 0                      None                     NaN     ...                NO
# 1                      None            1.073742e+09     ...                NO
# 2                      None            1.073742e+09     ...                NO
# 3                      None            1.073742e+09     ...                NO
# 4                      None            1.073742e+09     ...                NO
# 5                      None            1.073742e+09     ...                NO
# 6                      None            1.073742e+09     ...                NO
# 7                      None            1.073742e+09     ...                NO
# 8                      None            1.073742e+09     ...                NO
# 9                      None            1.073742e+09     ...                NO
# 10                     None            1.073742e+09     ...                NO
# 11                     None            1.073742e+09     ...                NO
#
#     identity_generation  identity_start identity_increment identity_maximum  \
# 0                  None            None               None             None
# 1                  None            None               None             None
# 2                  None            None               None             None
# 3                  None            None               None             None
# 4                  None            None               None             None
# 5                  None            None               None             None
# 6                  None            None               None             None
# 7                  None            None               None             None
# 8                  None            None               None             None
# 9                  None            None               None             None
# 10                 None            None               None             None
# 11                 None            None               None             None
#
#    identity_minimum identity_cycle is_generated generation_expression  \
# 0              None           None        NEVER                  None
# 1              None           None        NEVER                  None
# 2              None           None        NEVER                  None
# 3              None           None        NEVER                  None
# 4              None           None        NEVER                  None
# 5              None           None        NEVER                  None
# 6              None           None        NEVER                  None
# 7              None           None        NEVER                  None
# 8              None           None        NEVER                  None
# 9              None           None        NEVER                  None
# 10             None           None        NEVER                  None
# 11             None           None        NEVER                  None
#
#    is_updatable
# 0           YES
# 1           YES
# 2           YES
# 3           YES
# 4           YES
# 5           YES
# 6           YES
# 7           YES
# 8           YES
# 9           YES
# 10          YES
# 11          YES
#
# [12 rows x 44 columns]

# %%
df = pd.read_sql_query('''
          select * from product
          where "ProductTypeId"='6'and "PropertyGroupId"='13'
          limit 100
          ''', c)
df
# Out:
#      index ﻿ProductId BrandId ProductTypeId PropertyId PropertyValue  \
# 0   285864    7934202      47             6     207133
# 1   285875    7934202      47             6     207880
# 2   285876    7934202      47             6     208691
# 3   285877    7934202      47             6     208691
# 4   285878    7934202      47             6     208691
# 5   285879    7934202      47             6     208691
# 6   285880    7934202      47             6     208691
# 7   285883    7934202      47             6     219515
# 8   285884    7934202      47             6     219569
# 9   286819    7935073       8             6     207880
# 10  286820    7935073       8             6     208691
# 11  286821    7935073       8             6     208691
# 12  286822    7935073       8             6     208691
# 13  286823    7935073       8             6     208691
# 14  286824    7935073       8             6     219515
# 15  286825    7935073       8             6     219523
# 16  307757    7945649       1             6     207880
# 17  307758    7945649       1             6     208691
# 18  307759    7945649       1             6     208691
# 19  307760    7945649       1             6     208691
# 20  307761    7945649       1             6     208691
# 21  307762    7945649       1             6     219515
# 22  307763    7945649       1             6     219523
# 23  307923    7945692       5             6     207880
# 24  307924    7945692       5             6     208691
# 25  307925    7945692       5             6     208691
# 26  307926    7945692       5             6     208691
# 27  307927    7945692       5             6     208691
# 28  307928    7945692       5             6     219515
# 29  307929    7945692       5             6     219523
# ..     ...        ...     ...           ...        ...           ...
# 70  308438    7945892       1             6     219515
# 71  308439    7945892       1             6     219523
# 72  308731    7945979    5288             6     207880
# 73  308732    7945979    5288             6     208691
# 74  308733    7945979    5288             6     208691
# 75  308734    7945979    5288             6     208691
# 76  308735    7945979    5288             6     208691
# 77  308736    7945979    5288             6     219515
# 78  308737    7945979    5288             6     219523
# 79  308759    7945980    5288             6     207880
# 80  308760    7945980    5288             6     208691
# 81  308761    7945980    5288             6     208691
# 82  308762    7945980    5288             6     208691
# 83  308763    7945980    5288             6     208691
# 84  308764    7945980    5288             6     219515
# 85  308765    7945980    5288             6     219523
# 86  308786    7945981    5288             6     207880
# 87  308787    7945981    5288             6     208691
# 88  308788    7945981    5288             6     208691
# 89  308789    7945981    5288             6     208691
# 90  308790    7945981    5288             6     208691
# 91  308791    7945981    5288             6     219515
# 92  308792    7945981    5288             6     219523
# 93  308814    7945982    5288             6     207880
# 94  308815    7945982    5288             6     208691
# 95  308816    7945982    5288             6     208691
# 96  308817    7945982    5288             6     208691
# 97  308818    7945982    5288             6     208691
# 98  308819    7945982    5288             6     219515
# 99  308820    7945982    5288             6     219523
#
#    PropertyGroupId   PropertyGroup PropertyDefinitionId  \
# 0               13  Betriebssystem                 8766
# 1               13  Betriebssystem                10551
# 2               13  Betriebssystem                 7202
# 3               13  Betriebssystem                 7202
# 4               13  Betriebssystem                 7202
# 5               13  Betriebssystem                 7202
# 6               13  Betriebssystem                 7202
# 7               13  Betriebssystem                 7302
# 8               13  Betriebssystem                11288
# 9               13  Betriebssystem                10551
# 10              13  Betriebssystem                 7202
# 11              13  Betriebssystem                 7202
# 12              13  Betriebssystem                 7202
# 13              13  Betriebssystem                 7202
# 14              13  Betriebssystem                 7302
# 15              13  Betriebssystem                 6885
# 16              13  Betriebssystem                10551
# 17              13  Betriebssystem                 7202
# 18              13  Betriebssystem                 7202
# 19              13  Betriebssystem                 7202
# 20              13  Betriebssystem                 7202
# 21              13  Betriebssystem                 7302
# 22              13  Betriebssystem                 6885
# 23              13  Betriebssystem                10551
# 24              13  Betriebssystem                 7202
# 25              13  Betriebssystem                 7202
# 26              13  Betriebssystem                 7202
# 27              13  Betriebssystem                 7202
# 28              13  Betriebssystem                 7302
# 29              13  Betriebssystem                 6885
# ..             ...             ...                  ...
# 70              13  Betriebssystem                 7302
# 71              13  Betriebssystem                 6885
# 72              13  Betriebssystem                10551
# 73              13  Betriebssystem                 7202
# 74              13  Betriebssystem                 7202
# 75              13  Betriebssystem                 7202
# 76              13  Betriebssystem                 7202
# 77              13  Betriebssystem                 7302
# 78              13  Betriebssystem                 6885
# 79              13  Betriebssystem                10551
# 80              13  Betriebssystem                 7202
# 81              13  Betriebssystem                 7202
# 82              13  Betriebssystem                 7202
# 83              13  Betriebssystem                 7202
# 84              13  Betriebssystem                 7302
# 85              13  Betriebssystem                 6885
# 86              13  Betriebssystem                10551
# 87              13  Betriebssystem                 7202
# 88              13  Betriebssystem                 7202
# 89              13  Betriebssystem                 7202
# 90              13  Betriebssystem                 7202
# 91              13  Betriebssystem                 7302
# 92              13  Betriebssystem                 6885
# 93              13  Betriebssystem                10551
# 94              13  Betriebssystem                 7202
# 95              13  Betriebssystem                 7202
# 96              13  Betriebssystem                 7202
# 97              13  Betriebssystem                 7202
# 98              13  Betriebssystem                 7302
# 99              13  Betriebssystem                 6885
#
#                PropertyDefinition PropertyDefinitionOptionId  \
# 0                Mac OS X Version                     396179
# 1      Betriebssystem Architektur                      11110
# 2                         Sprache                       3988
# 3                         Sprache                       3989
# 4                         Sprache                       3990
# 5                         Sprache                       3991
# 6                         Sprache                       3992
# 7                  Betriebssystem                        339
# 8   Mitgeliefertes Betriebssystem                        339
# 9      Betriebssystem Architektur                      11110
# 10                        Sprache                       3988
# 11                        Sprache                       3989
# 12                        Sprache                       3990
# 13                        Sprache                       3991
# 14                 Betriebssystem                       5767
# 15                Windows Version                     277226
# 16     Betriebssystem Architektur                      11110
# 17                        Sprache                       3988
# 18                        Sprache                       3989
# 19                        Sprache                       3990
# 20                        Sprache                       3991
# 21                 Betriebssystem                       5767
# 22                Windows Version                     277226
# 23     Betriebssystem Architektur                      11110
# 24                        Sprache                       3988
# 25                        Sprache                       3989
# 26                        Sprache                       3990
# 27                        Sprache                       3991
# 28                 Betriebssystem                       5767
# 29                Windows Version                     324876
# ..                            ...                        ...
# 70                 Betriebssystem                       5767
# 71                Windows Version                     277226
# 72     Betriebssystem Architektur                      11110
# 73                        Sprache                       3988
# 74                        Sprache                       3989
# 75                        Sprache                       3990
# 76                        Sprache                       3991
# 77                 Betriebssystem                       5767
# 78                Windows Version                     277226
# 79     Betriebssystem Architektur                      11110
# 80                        Sprache                       3988
# 81                        Sprache                       3989
# 82                        Sprache                       3990
# 83                        Sprache                       3991
# 84                 Betriebssystem                       5767
# 85                Windows Version                     277226
# 86     Betriebssystem Architektur                      11110
# 87                        Sprache                       3988
# 88                        Sprache                       3989
# 89                        Sprache                       3990
# 90                        Sprache                       3991
# 91                 Betriebssystem                       5767
# 92                Windows Version                     277226
# 93     Betriebssystem Architektur                      11110
# 94                        Sprache                       3988
# 95                        Sprache                       3989
# 96                        Sprache                       3990
# 97                        Sprache                       3991
# 98                 Betriebssystem                       5767
# 99                Windows Version                     277226
#
#    PropertyDefinitionOption\n
# 0       10.13 (High Sierra)\n
# 1                    64-bit\n
# 2                   Deutsch\n
# 3               Französisch\n
# 4               Italienisch\n
# 5                  Englisch\n
# 6                  Spanisch\n
# 7                       Mac\n
# 8                       Mac\n
# 9                    64-bit\n
# 10                  Deutsch\n
# 11              Französisch\n
# 12              Italienisch\n
# 13                 Englisch\n
# 14                  Windows\n
# 15           Windows 10 Pro\n
# 16                   64-bit\n
# 17                  Deutsch\n
# 18              Französisch\n
# 19              Italienisch\n
# 20                 Englisch\n
# 21                  Windows\n
# 22           Windows 10 Pro\n
# 23                   64-bit\n
# 24                  Deutsch\n
# 25              Französisch\n
# 26              Italienisch\n
# 27                 Englisch\n
# 28                  Windows\n
# 29          Windows 10 Home\n
# ..                        ...
# 70                  Windows\n
# 71           Windows 10 Pro\n
# 72                   64-bit\n
# 73                  Deutsch\n
# 74              Französisch\n
# 75              Italienisch\n
# 76                 Englisch\n
# 77                  Windows\n
# 78           Windows 10 Pro\n
# 79                   64-bit\n
# 80                  Deutsch\n
# 81              Französisch\n
# 82              Italienisch\n
# 83                 Englisch\n
# 84                  Windows\n
# 85           Windows 10 Pro\n
# 86                   64-bit\n
# 87                  Deutsch\n
# 88              Französisch\n
# 89              Italienisch\n
# 90                 Englisch\n
# 91                  Windows\n
# 92           Windows 10 Pro\n
# 93                   64-bit\n
# 94                  Deutsch\n
# 95              Französisch\n
# 96              Italienisch\n
# 97                 Englisch\n
# 98                  Windows\n
# 99           Windows 10 Pro\n
#
# [100 rows x 12 columns]

# %%
pd.read_sql_query(
    '''SELECT * FROM product_only_ids
    WHERE NOT "PropertyValue" IS NULL
    LIMIT 100''', c
)
# Out:
#     index  ProductId  BrandId  ProductTypeId  PropertyId  PropertyValue  \
# 0       0    8779507     7608           1379      285325       387773.0
# 1       1    7417961    24068           1822      285127       388871.0
# 2       2    7418161     8669           1822      285127       388871.0
# 3       3    7418579    24243           1822      285127       388871.0
# 4       4    7423009     8585           1822      285127       388871.0
# 5       5    7423041     8585           1822      285127       388871.0
# 6       6    7423141     8442           1822      285127       388871.0
# 7       7    8597578     7733           1379      285325       387773.0
# 8       8    8691633     7472           1379      285325       387773.0
# 9       9    8725944    36086           1379      285325       387773.0
# 10     10    8076983      968           1379      285325       387773.0
# 11     11    8118228     8086           1379      285325       387773.0
# 12     12    8118698     7786           1379      285325       387773.0
# 13     13    7312388     7317           1822      285127       388871.0
# 14     14    7312854     7534           1822      285127       388871.0
# 15     15    7315178     8620           1822      285127       388871.0
# 16     16    7317182     7317           1822      285127       388871.0
# 17     17    8139136     7301           1379      285325       387773.0
# 18     18    8139822     8419           1379      285325       387773.0
# 19     19    8221812     8606           1379      285325       387773.0
# 20     20    8221814     8606           1379      285325       387773.0
# 21     21    8229200     7335           1379      285325       387773.0
# 22     22    8290819    10060           1379      285325       387773.0
# 23     23    7336587    24180           1822      285127       388871.0
# 24     24    7337539    24180           1822      285127       388871.0
# 25     25    8299059    34911           1379      285325       387773.0
# 26     26    8299693     8419           1379      285325       387773.0
# 27     27    8309806     7301           1379      285325       387773.0
# 28     28    8556464     8086           1379      285325       387773.0
# 29     29    7592387    24199           1821      285064         2004.0
# ..    ...        ...      ...            ...         ...            ...
# 70     70    7846916     7301           1380      285603       383683.0
# 71     71    8926290     7550           1380      285603       383683.0
# 72     72    2387697     7452           1380      285603       383683.0
# 73     73    9041002     7301           1379      285325       387773.0
# 74     74    9092326     7301           1380      285603       383683.0
# 75     75    8551753     7301           1380      285603       383683.0
# 76     76    2371001     5163           1380      285603       383683.0
# 77     77    2371142     5163           1380      285603       383683.0
# 78     78    2371235     5163           1380      285603       383683.0
# 79     79    2371267     5163           1380      285603       383683.0
# 80     80    2377117     7802           1380      285603       383683.0
# 81     81    2379439     7802           1380      285603       383683.0
# 82     82    2380400     7802           1380      285603       383683.0
# 83     83    7846382    25584           1821      285064         2000.0
# 84     84    9092401     7308           1379      285325       387773.0
# 85     85    7424349     7560           1822      285127       388871.0
# 86     86    7424365     7560           1822      285127       388871.0
# 87     87    7424381     7560           1822      285127       388871.0
# 88     88    7424422     7560           1822      285127       388871.0
# 89     89    7424549     7560           1822      285127       388871.0
# 90     90    6521573     7308           1380      285603       383683.0
# 91     91    6639647     7277           1380      285603       383683.0
# 92     92    7843474     7458           1821      285064         2001.0
# 93     93    7856049     7560           1821      285064         2011.0
# 94     94    7871893    24208           1821      285064         2012.0
# 95     95    7426237     7393           1822      285127       388871.0
# 96     96    7426244     7393           1822      285127       388871.0
# 97     97    7426246     7393           1822      285127       388871.0
# 98     98    7426255     7393           1822      285127       388871.0
# 99     99    7426269     7393           1822      285127       388871.0
#
#     PropertyGroupId  PropertyDefinitionId PropertyDefinitionOptionId
# 0               151                 19331                       None
# 1               151                 19331                       None
# 2               151                 19331                       None
# 3               151                 19331                       None
# 4               151                 19331                       None
# 5               151                 19331                       None
# 6               151                 19331                       None
# 7               151                 19331                       None
# 8               151                 19331                       None
# 9               151                 19331                       None
# 10              151                 19331                       None
# 11              151                 19331                       None
# 12              151                 19331                       None
# 13              151                 19331                       None
# 14              151                 19331                       None
# 15              151                 19331                       None
# 16              151                 19331                       None
# 17              151                 19331                       None
# 18              151                 19331                       None
# 19              151                 19331                       None
# 20              151                 19331                       None
# 21              151                 19331                       None
# 22              151                 19331                       None
# 23              151                 19331                       None
# 24              151                 19331                       None
# 25              151                 19331                       None
# 26              151                 19331                       None
# 27              151                 19331                       None
# 28              151                 19331                       None
# 29             1311                 10051                       None
# ..              ...                   ...                        ...
# 70              151                 19331                       None
# 71              151                 19331                       None
# 72              151                 19331                       None
# 73              151                 19331                       None
# 74              151                 19331                       None
# 75              151                 19331                       None
# 76              151                 19331                       None
# 77              151                 19331                       None
# 78              151                 19331                       None
# 79              151                 19331                       None
# 80              151                 19331                       None
# 81              151                 19331                       None
# 82              151                 19331                       None
# 83             1311                 10051                       None
# 84              151                 19331                       None
# 85              151                 19331                       None
# 86              151                 19331                       None
# 87              151                 19331                       None
# 88              151                 19331                       None
# 89              151                 19331                       None
# 90              151                 19331                       None
# 91              151                 19331                       None
# 92             1311                 10051                       None
# 93             1311                 10051                       None
# 94             1311                 10051                       None
# 95              151                 19331                       None
# 96              151                 19331                       None
# 97              151                 19331                       None
# 98              151                 19331                       None
# 99              151                 19331                       None
#
# [100 rows x 9 columns]

# %% [markdown]
# **pandas.crosstab()**: To compute a frequency table of the factors

# %%
pd.crosstab(index=df["ProductTypeId"],  columns="count")
# Out:
# col_0          count
# ProductTypeId
# 6                100

# %%
pd.read_sql_query('''
SELECT DISTINCT "PropertyDefinition","PropertyValue" FROM Product
WHERE "ProductTypeId"='6'
LIMIT 100
''', c)
# Out:
#    PropertyDefinition                PropertyValue
# 0          3D Anzeige         .0000000000000000000
# 1          3D Anzeige        1.0000000000000000000
# 2            4G (LTE)         .0000000000000000000
# 3            4G (LTE)        1.0000000000000000000
# 4        Akkuleistung   104400.0000000000000000000
# 5        Akkuleistung   105480.0000000000000000000
# 6        Akkuleistung   108000.0000000000000000000
# 7        Akkuleistung   109440.0000000000000000000
# 8        Akkuleistung   110520.0000000000000000000
# 9        Akkuleistung   111600.0000000000000000000
# 10       Akkuleistung   111888.0000000000000000000
# 11       Akkuleistung   115200.0000000000000000000
# 12       Akkuleistung   118800.0000000000000000000
# 13       Akkuleistung  1188000.0000000000000000000
# 14       Akkuleistung   122400.0000000000000000000
# 15       Akkuleistung   124200.0000000000000000000
# 16       Akkuleistung   126000.0000000000000000000
# 17       Akkuleistung   126720.0000000000000000000
# 18       Akkuleistung   129600.0000000000000000000
# 19       Akkuleistung   131040.0000000000000000000
# 20       Akkuleistung   133200.0000000000000000000
# 21       Akkuleistung   136800.0000000000000000000
# 22       Akkuleistung   139860.0000000000000000000
# 23       Akkuleistung   140400.0000000000000000000
# 24       Akkuleistung   142200.0000000000000000000
# 25       Akkuleistung   142920.0000000000000000000
# 26       Akkuleistung   144000.0000000000000000000
# 27       Akkuleistung   147600.0000000000000000000
# 28       Akkuleistung   147960.0000000000000000000
# 29       Akkuleistung   149040.0000000000000000000
# ..                ...                          ...
# 70       Akkuleistung   200880.0000000000000000000
# 71       Akkuleistung   201600.0000000000000000000
# 72       Akkuleistung   202176.0000000000000000000
# 73       Akkuleistung   203400.0000000000000000000
# 74       Akkuleistung   205200.0000000000000000000
# 75       Akkuleistung   206640.0000000000000000000
# 76       Akkuleistung   208080.0000000000000000000
# 77       Akkuleistung   208800.0000000000000000000
# 78       Akkuleistung   212400.0000000000000000000
# 79       Akkuleistung   216000.0000000000000000000
# 80       Akkuleistung   219600.0000000000000000000
# 81       Akkuleistung   220500.0000000000000000000
# 82       Akkuleistung   220680.0000000000000000000
# 83       Akkuleistung   221400.0000000000000000000
# 84       Akkuleistung   223200.0000000000000000000
# 85       Akkuleistung   223920.0000000000000000000
# 86       Akkuleistung   224640.0000000000000000000
# 87       Akkuleistung   226080.0000000000000000000
# 88       Akkuleistung   227880.0000000000000000000
# 89       Akkuleistung   228600.0000000000000000000
# 90       Akkuleistung   230400.0000000000000000000
# 91       Akkuleistung   232200.0000000000000000000
# 92       Akkuleistung   234000.0000000000000000000
# 93       Akkuleistung   237600.0000000000000000000
# 94       Akkuleistung   241200.0000000000000000000
# 95       Akkuleistung   244800.0000000000000000000
# 96       Akkuleistung   248400.0000000000000000000
# 97       Akkuleistung   252000.0000000000000000000
# 98       Akkuleistung   255600.0000000000000000000
# 99       Akkuleistung   258480.0000000000000000000
#
# [100 rows x 2 columns]

# %%
pd.read_sql_query('''
select *
from INFORMATION_SCHEMA.COLUMNS
where TABLE_NAME='product_purchase'
''', c)
# Out:
#    table_catalog table_schema        table_name      column_name  \
# 0          dslab       public  product_purchase            index
# 1          dslab       public  product_purchase           UserId
# 2          dslab       public  product_purchase       CustomerId
# 3          dslab       public  product_purchase         PortalId
# 4          dslab       public  product_purchase          OrderId
# 5          dslab       public  product_purchase        Timestamp
# 6          dslab       public  product_purchase        SessionId
# 7          dslab       public  product_purchase    CorrelationId
# 8          dslab       public  product_purchase  Items_ProductId
# 9          dslab       public  product_purchase  Items_ItemCount
# 10         dslab       public  product_purchase  Items_ItemPrice
#
#     ordinal_position column_default is_nullable         data_type  \
# 0                  1           None         YES            bigint
# 1                  2           None         YES            bigint
# 2                  3           None         YES            bigint
# 3                  4           None         YES            bigint
# 4                  5           None         YES            bigint
# 5                  6           None         YES            bigint
# 6                  7           None         YES  double precision
# 7                  8           None         YES              text
# 8                  9           None         YES            bigint
# 9                 10           None         YES            bigint
# 10                11           None         YES  double precision
#
#    character_maximum_length  character_octet_length     ...       is_identity  \
# 0                      None                     NaN     ...                NO
# 1                      None                     NaN     ...                NO
# 2                      None                     NaN     ...                NO
# 3                      None                     NaN     ...                NO
# 4                      None                     NaN     ...                NO
# 5                      None                     NaN     ...                NO
# 6                      None                     NaN     ...                NO
# 7                      None            1.073742e+09     ...                NO
# 8                      None                     NaN     ...                NO
# 9                      None                     NaN     ...                NO
# 10                     None                     NaN     ...                NO
#
#     identity_generation  identity_start identity_increment identity_maximum  \
# 0                  None            None               None             None
# 1                  None            None               None             None
# 2                  None            None               None             None
# 3                  None            None               None             None
# 4                  None            None               None             None
# 5                  None            None               None             None
# 6                  None            None               None             None
# 7                  None            None               None             None
# 8                  None            None               None             None
# 9                  None            None               None             None
# 10                 None            None               None             None
#
#    identity_minimum identity_cycle is_generated generation_expression  \
# 0              None           None        NEVER                  None
# 1              None           None        NEVER                  None
# 2              None           None        NEVER                  None
# 3              None           None        NEVER                  None
# 4              None           None        NEVER                  None
# 5              None           None        NEVER                  None
# 6              None           None        NEVER                  None
# 7              None           None        NEVER                  None
# 8              None           None        NEVER                  None
# 9              None           None        NEVER                  None
# 10             None           None        NEVER                  None
#
#    is_updatable
# 0           YES
# 1           YES
# 2           YES
# 3           YES
# 4           YES
# 5           YES
# 6           YES
# 7           YES
# 8           YES
# 9           YES
# 10          YES
#
# [11 rows x 44 columns]

# %%
#scrap
pd.read_sql_query(''' 
select * from product_purchase
where "OrderId" in
(select "OrderId"
from (select * from product_purchase limit 1000) as test 
group by "OrderId" 
having count(distinct "Items_ItemCount")=1
limit 10)
''', c)
# Out:
#       index  UserId  CustomerId  PortalId  OrderId   Timestamp SessionId  \
# 0   2225756  599294      754796        25   997840  1403646546      None
# 1   2225849  485986      644155        25   613002  1384334250      None
# 2   2225931  594400      750082        25   978231  1403303772      None
# 3   2226059  568919      725776        25   910754  1401643921      None
# 4   2226062  448929      607523        25   907057  1401470347      None
# 5   2226065  274002      434181        25   957007  1402851588      None
# 6   2226069  487770      645919        25   881907  1400968041      None
# 7   2226089  517985      675767        25   739184  1392129837      None
# 8   2226461  503687      661723        25  1009859  1403885701      None
# 9   2226507  553200      710443        25   991600  1403532242      None
# 10  1899962  599294      754796        25   997840  1403646546      None
# 11  1993579  553200      710443        25   991600  1403532242      None
# 12  1883185  487770      645919        25   881907  1400968041      None
# 13  1676449  274002      434181        25   957007  1402851588      None
# 14  1987047  448929      607523        25   907057  1401470347      None
# 15  1454471  517985      675767        25   739184  1392129837      None
#
#    CorrelationId  Items_ProductId  Items_ItemCount  Items_ItemPrice
# 0           None           659848                2             5.36
# 1           None           417363                2            57.00
# 2           None           362620                2           841.80
# 3           None          2485655                2           399.00
# 4           None           225990                2            16.60
# 5           None           639799                2            51.80
# 6           None           761746                2             5.38
# 7           None           245073                2            21.90
# 8           None          2367354                2            69.00
# 9           None           762985                2            47.70
# 10          None           434114                1             5.36
# 11          None          2481431                1           569.00
# 12          None           434114                1             5.38
# 13          None           449063                1           299.00
# 14          None           416080                1           210.00
# 15          None           233780                1            22.00

# %%
pd.read_sql_query('''

SELECT * FROM product_purchase
WHERE (SELECT DISTINCT "UserId", "Timestamp", "Items_ProductId" FROM product_purchase)
''', c)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# ProgrammingError: subquery must return only one column
# LINE 4: WHERE (SELECT DISTINCT "UserId", "Timestamp", "Items_Product...
#               ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-92-b8b0057f53e4> in <module>
#       3 SELECT * FROM product_purchase
#       4 WHERE (SELECT DISTINCT "UserId", "Timestamp", "Items_ProductId" FROM product_purchase)
# ----> 5 ''', c)
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
#     313         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 314         parse_dates=parse_dates, chunksize=chunksize)
#     315
#     316
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1061         args = _convert_params(sql, params)
#    1062
# -> 1063         result = self.execute(*args)
#    1064         columns = result.keys()
#    1065
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     952     def execute(self, *args, **kwargs):
#     953         """Simple passthrough to SQLAlchemy connectable"""
# --> 954         return self.connectable.execute(*args, **kwargs)
#     955
#     956     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     940         """
#     941         if isinstance(object, util.string_types[0]):
# --> 942             return self._execute_text(object, multiparams, params)
#     943         try:
#     944             meth = object._execute_on_connection
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1102             statement,
#    1103             parameters,
# -> 1104             statement, parameters
#    1105         )
#    1106         if self._has_events or self.engine._has_events:
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~/.local/share/virtualenvs/dslab-I_4c5zFJ/lib/python3.5/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#     511     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.ProgrammingError) subquery must return only one column
# LINE 4: WHERE (SELECT DISTINCT "UserId", "Timestamp", "Items_Product...
#               ^
#  [SQL: '\n\nSELECT * FROM product_purchase\nWHERE (SELECT DISTINCT "UserId", "Timestamp", "Items_ProductId" FROM product_purchase)\n'] (Background on this error at: http://sqlalche.me/e/f405)
